# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.impute import KNNImputer
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import LabelBinarizer
from scipy.stats import chi2_contingency

# %%
sns.set_theme()

# %% [markdown]
# ### Step 1:
# Read in the three csv files as data frames. Combine all three data frames using admission_id into one named all_df, retaining all rows from Admissions.csv.

# %%
admin_df = pd.read_csv('C:/Users/rparg/Documents/Coding_Practice/Assignments/Admissions.csv').set_index('admission_id')
lab_df = pd.read_csv('C:/Users/rparg/Documents/Coding_Practice/Assignments/Lab.csv').set_index('admission_id')
tran_df = pd.read_csv('C:/Users/rparg/Documents/Coding_Practice/Assignments/Transfusions.csv').set_index('admission_id')

# %%
# Length of stay in days
admin_df['len_stay'] = (pd.to_datetime(admin_df['discharge_date']) - pd.to_datetime(admin_df['admission_date'])).dt.days

# Combine date and time columns together
#admin_df['discharge_time_total'] = ...
admin_df['admission_time'] = admin_df['admission_time'].fillna('12:00')
admin_df['admin_datetime'] = pd.to_datetime(admin_df['admission_date'] + ' ' + admin_df['admission_time'])

admin_df[['admission_date','admission_time', 'admin_datetime']]
admin_df['disch_datetime'] = pd.to_datetime(admin_df['discharge_date'] + ' ' + admin_df['discharge_time'])

admin_df['stay_datetime'] = (admin_df['disch_datetime'] - admin_df['admin_datetime'])

# %%
# add in source column?
# joins - check that each one performs properly (is one-to-one)
# no duplicates
# lengths all add up correctly (dimensions)

# %%
# Comorbidity index
admin_df['charlson_comorbidity_index'].replace({'0':0,'1':1,'2+':2}, inplace = True)

# one hot sex
admin_df['sex'].replace({'M':-0.5,'F':+0.5}, inplace = True)

# %%
admin_df = admin_df.join(pd.get_dummies(admin_df['hospital']))

# %%
admin_df
# Out:
#               patient_id admission_date admission_time discharge_date  \
# admission_id
# 3602               34208     2011-09-07          12:00     09/11/2011
# 2790               90930     2008-07-22          06:19     07/24/2008
# 8755               97765     2002-08-24          14:28     08/27/2002
# 9260               17941     2007-01-12          09:39     01/26/2007
# 5317               36532     2003-09-24          13:37     10/12/2003
# ...                  ...            ...            ...            ...
# 6028               86717     2002-12-27          16:49     01/11/2003
# 2408               42427     2008-01-26          12:58     01/28/2008
# 6356               22610     2007-05-16          15:10     05/20/2007
# 6833               72792     2007-02-19          09:50     03/03/2007
# 8516               82083     2010-02-23          21:37     03/02/2010
#
#              discharge_time                           hospital   age  sex  \
# admission_id
# 3602                  13:16         St. Joseph's Health Centre   NaN -0.5
# 2790                  17:54             St. Michael's Hospital  48.0 -0.5
# 8755                  08:14               Mount Sinai Hospital  59.0  0.5
# 9260                  11:10  Sunnybrook Health Sciences Centre  57.0 -0.5
# 5317                  16:23           Toronto Western Hospital  51.0  0.5
# ...                     ...                                ...   ...  ...
# 6028                  22:45           Toronto Western Hospital   NaN  0.5
# 2408                  01:45             St. Michael's Hospital  50.0 -0.5
# 6356                  07:04  Sunnybrook Health Sciences Centre  52.0 -0.5
# 6833                  03:07           Toronto Western Hospital  50.0 -0.5
# 8516                  03:51             St. Michael's Hospital  62.0 -0.5
#
#               charlson_comorbidity_index  lap_score  len_stay  \
# admission_id
# 3602                                 1.0         45         4
# 2790                                 1.0         46         2
# 8755                                 0.0         35         3
# 9260                                 1.0         18        14
# 5317                                 1.0         21        18
# ...                                  ...        ...       ...
# 6028                                 2.0         22        15
# 2408                                 1.0         38         2
# 6356                                 1.0         23         4
# 6833                                 0.0         60        12
# 8516                                 1.0          5         7
#
#                   admin_datetime      disch_datetime    stay_datetime  \
# admission_id
# 3602         2011-09-07 12:00:00 2011-09-11 13:16:00  4 days 01:16:00
# 2790         2008-07-22 06:19:00 2008-07-24 17:54:00  2 days 11:35:00
# 8755         2002-08-24 14:28:00 2002-08-27 08:14:00  2 days 17:46:00
# 9260         2007-01-12 09:39:00 2007-01-26 11:10:00 14 days 01:31:00
# 5317         2003-09-24 13:37:00 2003-10-12 16:23:00 18 days 02:46:00
# ...                          ...                 ...              ...
# 6028         2002-12-27 16:49:00 2003-01-11 22:45:00 15 days 05:56:00
# 2408         2008-01-26 12:58:00 2008-01-28 01:45:00  1 days 12:47:00
# 6356         2007-05-16 15:10:00 2007-05-20 07:04:00  3 days 15:54:00
# 6833         2007-02-19 09:50:00 2007-03-03 03:07:00 11 days 17:17:00
# 8516         2010-02-23 21:37:00 2010-03-02 03:51:00  6 days 06:14:00
#
#               Mount Sinai Hospital  St. Joseph's Health Centre  \
# admission_id
# 3602                             0                           1
# 2790                             0                           0
# 8755                             1                           0
# 9260                             0                           0
# 5317                             0                           0
# ...                            ...                         ...
# 6028                             0                           0
# 2408                             0                           0
# 6356                             0                           0
# 6833                             0                           0
# 8516                             0                           0
#
#               St. Michael's Hospital  Sunnybrook Health Sciences Centre  \
# admission_id
# 3602                               0                                  0
# 2790                               1                                  0
# 8755                               0                                  0
# 9260                               0                                  1
# 5317                               0                                  0
# ...                              ...                                ...
# 6028                               0                                  0
# 2408                               1                                  0
# 6356                               0                                  1
# 6833                               0                                  0
# 8516                               1                                  0
#
#               Toronto Western Hospital
# admission_id
# 3602                                 0
# 2790                                 0
# 8755                                 0
# 9260                                 0
# 5317                                 1
# ...                                ...
# 6028                                 1
# 2408                                 0
# 6356                                 0
# 6833                                 1
# 8516                                 0
#
# [5231 rows x 19 columns]

# %%
# Join together
all_df = admin_df.join([lab_df,tran_df], how = 'left', sort = True)

# %%
all_df.describe()
# Out:
#          patient_id         age          sex  charlson_comorbidity_index  \
# count   5231.000000  4604.00000  5231.000000                 4970.000000
# mean   54170.202829    54.94874     0.041388                    1.025755
# std    26121.399502     5.05146     0.498332                    0.796034
# min    10017.000000    38.00000    -0.500000                    0.000000
# 25%    30970.000000    51.00000    -0.500000                    0.000000
# 50%    54736.000000    55.00000     0.500000                    1.000000
# 75%    76768.500000    58.00000     0.500000                    2.000000
# max    99984.000000    74.00000     0.500000                    2.000000
#
#          lap_score     len_stay            stay_datetime  \
# count  5231.000000  5231.000000                     5231
# mean     27.528197    10.879373  10 days 21:04:59.713247
# std      21.423248     7.990325   7 days 23:50:16.012516
# min       0.000000  -360.000000      -360 days +08:36:00
# 25%      11.000000     6.000000          5 days 16:42:30
# 50%      23.000000    11.000000         10 days 21:57:00
# 75%      40.000000    16.000000         16 days 07:52:30
# max     136.000000    21.000000         21 days 20:12:00
#
#        Mount Sinai Hospital  St. Joseph's Health Centre  \
# count           5231.000000                 5231.000000
# mean               0.144905                    0.133053
# std                0.352039                    0.339664
# min                0.000000                    0.000000
# 25%                0.000000                    0.000000
# 50%                0.000000                    0.000000
# 75%                0.000000                    0.000000
# max                1.000000                    1.000000
#
#        St. Michael's Hospital  Sunnybrook Health Sciences Centre  \
# count             5231.000000                        5231.000000
# mean                 0.270120                           0.244886
# std                  0.444064                           0.430061
# min                  0.000000                           0.000000
# 25%                  0.000000                           0.000000
# 50%                  0.000000                           0.000000
# 75%                  1.000000                           0.000000
# max                  1.000000                           1.000000
#
#        Toronto Western Hospital  result_value
# count               5231.000000   3609.000000
# mean                   0.207035     81.539762
# std                    0.405220     94.470176
# min                    0.000000      0.000000
# 25%                    0.000000      3.600000
# 50%                    0.000000     48.600000
# 75%                    0.000000    140.900000
# max                    1.000000    584.400000

# %% [markdown]
# #### EDA

# %%
admin_df.head()
# Out:
#               patient_id admission_date admission_time discharge_date  \
# admission_id
# 3602               34208     2011-09-07          12:00     09/11/2011
# 2790               90930     2008-07-22          06:19     07/24/2008
# 8755               97765     2002-08-24          14:28     08/27/2002
# 9260               17941     2007-01-12          09:39     01/26/2007
# 5317               36532     2003-09-24          13:37     10/12/2003
#
#              discharge_time                           hospital   age  sex  \
# admission_id
# 3602                  13:16         St. Joseph's Health Centre   NaN -0.5
# 2790                  17:54             St. Michael's Hospital  48.0 -0.5
# 8755                  08:14               Mount Sinai Hospital  59.0  0.5
# 9260                  11:10  Sunnybrook Health Sciences Centre  57.0 -0.5
# 5317                  16:23           Toronto Western Hospital  51.0  0.5
#
#               charlson_comorbidity_index  lap_score  len_stay  \
# admission_id
# 3602                                 1.0         45         4
# 2790                                 1.0         46         2
# 8755                                 0.0         35         3
# 9260                                 1.0         18        14
# 5317                                 1.0         21        18
#
#                   admin_datetime      disch_datetime    stay_datetime  \
# admission_id
# 3602         2011-09-07 12:00:00 2011-09-11 13:16:00  4 days 01:16:00
# 2790         2008-07-22 06:19:00 2008-07-24 17:54:00  2 days 11:35:00
# 8755         2002-08-24 14:28:00 2002-08-27 08:14:00  2 days 17:46:00
# 9260         2007-01-12 09:39:00 2007-01-26 11:10:00 14 days 01:31:00
# 5317         2003-09-24 13:37:00 2003-10-12 16:23:00 18 days 02:46:00
#
#               Mount Sinai Hospital  St. Joseph's Health Centre  \
# admission_id
# 3602                             0                           1
# 2790                             0                           0
# 8755                             1                           0
# 9260                             0                           0
# 5317                             0                           0
#
#               St. Michael's Hospital  Sunnybrook Health Sciences Centre  \
# admission_id
# 3602                               0                                  0
# 2790                               1                                  0
# 8755                               0                                  0
# 9260                               0                                  1
# 5317                               0                                  0
#
#               Toronto Western Hospital
# admission_id
# 3602                                 0
# 2790                                 0
# 8755                                 0
# 9260                                 0
# 5317                                 1

# %%
admin_grouped_by_age_df = admin_df.groupby('age',as_index=False).agg({"charlson_comorbidity_index":lambda x: x.isnull().sum(),'patient_id':'count',"admission_time":lambda x: x.isnull().sum()})
admin_grouped_by_age_df['charlson_null_fraction'] = admin_grouped_by_age_df['charlson_comorbidity_index']/admin_grouped_by_age_df['patient_id']
admin_grouped_by_age_df['admission_time_null_fraction'] = admin_grouped_by_age_df['admission_time']/admin_grouped_by_age_df['patient_id']
admin_grouped_by_age_df['age'] = admin_grouped_by_age_df['age'].astype(int)

# %%
f,ax = plt.subplots(figsize=(14,6))
sns.barplot(data = admin_grouped_by_age_df, x='age', y='charlson_null_fraction' ,ax=ax)
plt.show()

# %%
admin_grouped_by_hospital_df = admin_df.groupby('hospital',as_index=False).agg({"age":lambda x: x.isnull().sum(),'patient_id':'count'})
admin_grouped_by_hospital_df['age_fraction'] = admin_grouped_by_hospital_df['age']/admin_grouped_by_hospital_df['patient_id']

# %%
f,ax = plt.subplots(figsize=(14,6))
sns.barplot(data = admin_grouped_by_hospital_df, x='hospital', y='age_fraction' ,ax=ax)
plt.show()

# %%
#table = pd.DataFrame(admin_df[~admin_df["charlson_comorbidity_index"].isnull()].groupby("age").count()['patient_id']).join(admin_df[admin_df["charlson_comorbidity_index"].isnull()].groupby("age").count()['patient_id'])
#chi2, p, dof, ex = chi2_contingency(table)
#print("The p-value is esqual to {}".format(p))

# %%
chi2, p, dof, ex = chi2_contingency(table)
print("The p-value is esqual to {}".format(p))
# Out:
# The p-value is esqual to 0.12423828190683604

# %%
all_df
# Out:
#                                        hospital   age sex  \
# admission_id
# 3602                 St. Joseph's Health Centre   NaN   M
# 2790                     St. Michael's Hospital  48.0   M
# 8755                       Mount Sinai Hospital  59.0   F
# 9260          Sunnybrook Health Sciences Centre  57.0   M
# 5317                   Toronto Western Hospital  51.0   F
# ...                                         ...   ...  ..
# 6028                   Toronto Western Hospital   NaN   F
# 2408                     St. Michael's Hospital  50.0   M
# 6356          Sunnybrook Health Sciences Centre  52.0   M
# 6833                   Toronto Western Hospital  50.0   M
# 8516                     St. Michael's Hospital  62.0   M
#
#              charlson_comorbidity_index  lap_score test_code  result_value  \
# admission_id
# 3602                                  1         45       NaN           NaN
# 2790                                  1         46       ALB           2.2
# 8755                                  0         35       ALB           1.8
# 9260                                  1         18       RBC         172.1
# 5317                                  1         21       ALB           2.5
# ...                                 ...        ...       ...           ...
# 6028                                 2+         22       NaN           NaN
# 2408                                  1         38       NaN           NaN
# 6356                                  1         23    TCO2PL          70.8
# 6833                                  0         60    CREAPL         547.9
# 8516                                  1          5    CREAPL         283.2
#
#              rbc_transfusion platelet_transfusion plasma_transfusion
# admission_id
# 3602                     NaN                  NaN                NaN
# 2790                     NaN                  NaN                NaN
# 8755                   False                False               True
# 9260                     NaN                  NaN                NaN
# 5317                     NaN                  NaN                NaN
# ...                      ...                  ...                ...
# 6028                     NaN                  NaN                NaN
# 2408                     NaN                  NaN                NaN
# 6356                     NaN                  NaN                NaN
# 6833                     NaN                  NaN                NaN
# 8516                     NaN                  NaN                NaN
#
# [5231 rows x 10 columns]

# %%
### EDA on each dataset

# %% [markdown]
# pd.describe, some graphs, unique values, value_counts()

# %%
### Fix any missing values/ make decisions

# %%
### Deal with any weirdness in data 
 # - things that may happen when information is manually entered
 # - look at unique strings in columns -> weird spellings?
 # - are things that are supposed to be numerical actually numbers?
 # - are there any clear outliers where maybe something went wrong?

# Show these results

# %% [markdown]
# Categorical Column ''''blah blab blah''' is changed to xyz

# %%
all_df[all_df['rbc_transfusion']== False]['age'].dropna()
#table = pd.crosstab(all_df[all_df['rbc_transfusion']== True]['age'].dropna(), all_df[all_df['rbc_transfusion']== False]['age'].dropna())
#chi2, p, dof, ex = chi2_contingency(table)
#print("The p-value is esqual to {}".format(p))\
# Out:
# admission_id
# 8755    59.0
# 5589    65.0
# 6208    54.0
# 4134    46.0
# 2674    59.0
#         ...
# 7116    59.0
# 6352    51.0
# 4686    49.0
# 1839    63.0
# 6925    54.0
# Name: age, Length: 255, dtype: float64

# %% [markdown]
# ### Step 2:
# Impute the missing age and charlson_comorbidity_index values in any way you see fit. Briefly explain how the imputation method(s) might affect a statistical model that uses these variables as predictors.

# %%
imputer = KNNImputer(n_neighbors=2, weights="uniform")
imputer.fit_transform(ad_df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-a0f0e15dc63f> in <module>
#       1 imputer = KNNImputer(n_neighbors=2, weights="uniform")
# ----> 2 imputer.fit_transform(ad_df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     688         if y is None:
#     689             # fit method of arity 1 (unsupervised transformation)
# --> 690             return self.fit(X, **fit_params).transform(X)
#     691         else:
#     692             # fit method of arity 2 (supervised transformation)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\impute\_knn.py in fit(self, X, y)
#     182                 "Expected n_neighbors > 0. Got {}".format(self.n_neighbors))
#     183
# --> 184         X = self._validate_data(X, accept_sparse=False, dtype=FLOAT_DTYPES,
#     185                                 force_all_finite=force_all_finite,
#     186                                 copy=self.copy)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     418                     f"requires y to be passed, but the target y is None."
#     419                 )
# --> 420             X = check_array(X, **check_params)
#     421             out = X
#     422         else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     597                     array = array.astype(dtype, casting="unsafe", copy=False)
#     598                 else:
# --> 599                     array = np.asarray(array, order=order, dtype=dtype)
#     600             except ComplexWarning:
#     601                 raise ValueError("Complex data not supported\n"
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py in asarray(a, dtype, order)
#      83
#      84     """
# ---> 85     return array(a, dtype, copy=False, order=order)
#      86
#      87
#
# ValueError: could not convert string to float: "St. Joseph's Health Centre"

# %% [markdown]
# ### Step 3:
# Determine if there is a significant difference in age between patients who had an rbc_transfusion and patients that did not. Determine if there is a significant difference in sex between these groups.

# %%
table = pd.crosstab(all_df[, X_train["age"])
chi2, p, dof, ex = chi2_contingency(table)
print("The p-value is esqual to {}".format(p))

# %% [markdown]
# ### Step 4:
# Fit a linear regression model using the result_value of the “Platelet Count” lab tests as the dependent variable and age, sex, and hospital as the independent variables. Interpret the results.

# %% [markdown]
# ### Step 5:
# Create a plot that demonstrates the relationship between length_of_stay (discharge date and time minus admission date and time) and charlson_comorbidity_index. Briefly describe how you would change the visualization to add age as a third variable.

# %% [markdown]
# ### Step 6:
# Fit a statistical model of your choosing to predict the result_value of the “Hemoglobin” lab tests and evaluate its performance. Explain your choices and how you might improve the model if you had to iterate on it. What other clinical variables would you be interested in adding to the model (they don’t have to be in the provided datasets)?
